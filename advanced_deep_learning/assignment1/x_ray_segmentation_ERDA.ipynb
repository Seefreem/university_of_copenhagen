# %% [markdown]
# # U-Net segmentation example
# ### Advanced Deep Learning 2024
# This notebook was originally written by Mathias Perslev. It has been changed slightly by Christian Igel and subsequently slightly updated Stefan Sommer (mailto:sommer@di.ku.dk) and Jon Sporring (mailto:sporring@di.ku.dk).
#
# We consider the data described in:
#
# Bram van Ginneken, Mikkel B. Stegmann, Marco Loog. [Segmentation of anatomical structures in chest radiographs using supervised methods: a comparative study on a public database](https://doi.org/10.1016/j.media.2005.02.002). *Medical Image Analysis* 10(1): 19-40, 2006

# %% [markdown]
# ## Installs
#
# On non-colab system, is usually good to make an environment and install necessary tools there. E.g., anaconda->jupyter->terminal create an environment, if you have not already, and activate it:
# ```
# conda create -n adl python=3.9
# conda activate adl
# ```
# then install missing packages such as:
# ```
# conda install ipykernel torch matplotlib torchmetrics scikit-image jpeg
# conda install -c conda-forge segmentation-models-pytorch ipywidgets
# ```
# and if you want to add it to jupyter's drop-down menu
# ```
# ipython kernel install --user --name=adl
# ```
# Now reload the jupyter-notebook's homepage and make a new or load an existing file. On colab, the tools have to be installed everytime

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False
if IN_COLAB:
    # !pip3 install torch matplotlib torchmetrics scikit-image segmentation-models-pytorch

# %% [markdown]
# ## Imports

# %%
import torch
from torch import nn as nn
from torch.nn import functional as F
from torchvision.datasets.utils import download_url

from torch import Tensor

import torchmetrics

import segmentation_models_pytorch as smp

import os
import matplotlib.pyplot as plt
import numpy as np

from pprint import pformat
from skimage.transform import resize
from pathlib import Path
from glob import glob
from matplotlib.pyplot import imread
from collections import defaultdict

# %% [markdown]
# ## Set global device

# %%
# GPU support?
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)

# Setup WandB
import wandb
# init wandb
run = wandb.init(project='x_ray_segmentation_ERDA')
# set config
config = wandb.config
config.learning_rate = 0.0001
config.epochs = 100
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# device: cuda:0
# wandb: Currently logged in as: shilingdeng7187 (adl_shilingdeng). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/shiling/git/university_of_copenhagen/advanced_deep_learning/assignment1/wandb/run-20240425_195144-xilmn92m</code>
# Syncing run <strong><a href='https://wandb.ai/adl_shilingdeng/x_ray_segmentation_ERDA/runs/xilmn92m' target="_blank">copper-plasma-1</a></strong> to <a href='https://wandb.ai/adl_shilingdeng/x_ray_segmentation_ERDA' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adl_shilingdeng/x_ray_segmentation_ERDA' target="_blank">https://wandb.ai/adl_shilingdeng/x_ray_segmentation_ERDA</a>
#  View run at <a href='https://wandb.ai/adl_shilingdeng/x_ray_segmentation_ERDA/runs/xilmn92m' target="_blank">https://wandb.ai/adl_shilingdeng/x_ray_segmentation_ERDA/runs/xilmn92m</a>

# %% [markdown]
# ## Functions
# ### Loading data sets

# %%
def load_npz_dataset(path, keys=('x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test')):
    archive = np.load(path)
    return [archive.get(key) for key in keys]

def as_torch_dataset(x_arr, y_arr):
    """
    Takes two numpy arrays of data points and labels (x_arr and y_arr, respectively) and
    returns a torch TensorDataset object.

    Returns: torch.utils.data.TensorDataset
    """
    dataset = torch.utils.data.TensorDataset(
        torch.FloatTensor(x_arr),
        torch.FloatTensor(y_arr)
    )
    return dataset

# %% [markdown]
# ### Visualization

# %%
def plot_image_with_segmentation(image, segmentation, ax=None):
    """
    Plots an image with overlayed segmentation mask. Segmentation is thresholded at 0.5

    Returns: plt.fig and ax objects
    """
    if ax is None:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.axis("off")

    im = image.cpu().detach().numpy()
    segm = segmentation.cpu().detach().numpy()
    ax.imshow(im.squeeze(), cmap="gray")
    mask = segm < 0.5
    ax.imshow(mask.squeeze(), cmap="Set1", alpha=0.5)
    return plt.gcf(), ax

# %% [markdown]
# ### Evaluating a model on data

# %%
def evaluate_model_on_single_image(model, x, device=device):
    """
    Evaluate a model on a single data point on the device.

    Returns: model(x)
    """
    with torch.no_grad():
        x = x.to(device)
        return model(x.view(1, *x.shape))

# %%
def evaluate_model(model, data_loader, metrics_dict, reduction=True, device=device):
    """
    Evaluate a model 'model' on all batches of a torch DataLoader 'data_loader'.
    On each batch, compute all metric functions stored in dictionary 'metrics_dict'.

    Returns: dict of metric_name: (list of batch-wise metrics if reduction == False, else single scalar)
    """

    # defaultdict(list) returns a dictionary-like object with default_factory list.
    # When a new key is encountered, an entry is automatically created of type default_factory.
    metrics = defaultdict(list)
    with torch.no_grad():
        for i, (batch_x, batch_y) in enumerate(data_loader):
            # Predict on batch
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            logits = model(batch_x)

            # Compute all metrics
            for metric_name, metric_func in metrics_dict.items():
                value = metric_func(logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                metrics[metric_name].append(value)

    if reduction == True:
        # Return mean values
        return {key: np.mean(value) for key, value in metrics.items()}
    else:
        return metrics

# %% [markdown]
# ### Saving and loading model and optimizer state

# %%
def save_model(model, path, optimizer=None):
    """
    Saves the state_dict of a torch model and optional optimizer to 'path'
    Returns: None
    """
    state = {"model": model.state_dict()}
    if optimizer is not None:
        state["optimizer"] = optimizer.state_dict()
    torch.save(state, path)


def load_model(model, path, optimizer=None):
    """
    Loads the state_dict of a torch model and optional optimizer from 'path'
    Returns: None
    """
    state = torch.load(path)
    model.load_state_dict(state["model"])
    if optimizer is not None:
        optimizer.load_state_dict(state["optimizer"])

# %% [markdown]
# ### Plotting training/validation histories

# %%
def plot_histories(train_history=None, val_history=None, label="Loss"):
    """
    Takes a list of training and/or validation metrics and plots them
    Returns: plt.figure and ax objects
    """
    if not train_history and not val_history:
        raise ValueError("Must specify at least one of 'train_histories' and 'val_histories'")
    fig = plt.figure(figsize=(5, 3))
    ax = fig.add_subplot(111)

    epochs = np.arange(len(train_history or val_history))
    if train_history:
        ax.plot(epochs, train_history, label="Training", color="black")
    if val_history:
        ax.plot(epochs, val_history, label="Validation", color="darkred")

    ax.set_xlabel("Epoch")
    ax.set_ylabel(label)
    ax.legend(loc=0)

    return fig, ax

# %% [markdown]
# ### Main training loop
#
# We want to track the F1 score during training. This generates some additional code.

# %%
def run_one_epoch(model, loss, optimizer, train_loader, val_loader, n_epochs, metrics_dict, device=device):
    """
    Run 1 epoch of training
    Changes to model parameters and optimizer occour internally (state updates)
    Returns:
        two dictionaries, training and a validation metrics
    """
    train_losses = []
    for i, (batch_x, batch_y) in enumerate(train_loader):
        # Zero out stored gradients for all parameters
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()

        print(f"   -- Batch {i+1}/{len(train_loader)}", end=" / ")
        # Predict on batch
        logits = model(batch_x)

        # Compute loss function
        loss_tensor = loss(logits, batch_y)
        loss_scalar = loss_tensor.detach().cpu().numpy()
        train_losses.append(loss_scalar)
        print("Loss: ", loss_scalar)

        # Backprop and step
        loss_tensor.backward()
        optimizer.step()

    # Run validation
    print("   Validation running...")
    val_metrics = evaluate_model(
        model=model,
        data_loader=val_loader,
        metrics_dict=metrics_dict
    )
    # Return loss and metrics as dicts
    return {"loss": np.mean(train_losses)}, val_metrics


def merge_list_of_dicts(list_of_dicts):
    """
    Takes a list of dictionaries and merges them into a single dictionary pointing to lists

    E.g. [{"loss": 5}, {"loss": 3}, {"loss": -2, "F1": 0.5}] --> {"loss": [5, 3, -2], "F1": [0.5]}

    Returns: dict
    """
    merged = defaultdict(list)
    for dict_ in list_of_dicts:
        for value, key in dict_.items():
            merged[value].append(key)
    return merged


def training_loop(model, loss, optimizer, train_loader, val_loader, n_epochs, init_epoch=None, metrics_dict=None, save_path=None):
    """
    Run training of a model given a loss function, optimizer and a set of training and validation data.
    Supports computing additional metrics on the validation set (only) via the metrics_dict param.
    Specify save_path to store the model at each epoch.

    Returns:
        Two lists of metric dictionaries for each epoch for training and validation, specifically
    """
    train_history, val_history = [], []

    metrics_with_loss = {"loss": loss}
    if metrics_dict is not None:
        metrics_with_loss.update(metrics_dict)

    if init_epoch == None:
        init_epoch = 0
    try:
        for i in range(init_epoch, n_epochs):
            print(f"Epoch {i+1}/{n_epochs}")
            train_metrics, val_metrics = run_one_epoch(
                model=model,
                loss=loss,
                optimizer=optimizer,
                train_loader=train_loader,
                val_loader=val_loader,
                n_epochs=n_epochs,
                metrics_dict=metrics_with_loss
            )
            print("   Mean epoch metrics:")
            print(f"   Training:   {pformat(train_metrics)}")
            print(f"   Validation: {pformat(val_metrics)}")
            train_history.append(train_metrics), val_history.append(val_metrics)
            # Log to WandB
            wandb.log({'epoch': i+1, 'training loss': train_metrics['loss'], 'validation loss':val_metrics['loss']})
            wandb.watch(model, loss, log="all") # Hook into the torch model to collect gradients and the topology.

            if save_path:
                save_path_epoch = f"epoch_{i+1}_{save_path}"
                print(f"   Saving to: {save_path_epoch}")
                save_model(model, save_path_epoch, optimizer)
                old_path_epoch = f"epoch_{i}_{save_path}"
                if os.path.exists(old_path_epoch):
                    os.remove(old_path_epoch)

    except KeyboardInterrupt:
        print("Training stopped.")
        pass

    # Merge list of training and validation dicts into single dicts
    return merge_list_of_dicts(train_history), merge_list_of_dicts(val_history)

# %% [markdown]
# ## Main program
# ### Mount Google drive when using Google Colab

# %%
# If you are working from Colab, better mount your google drive and change directory appropriately.
try:
    from google.colab import drive
    drive.mount('/content/gdrive/')
    os.chdir('gdrive/MyDrive/Colab Notebooks/ADL/assignment1')
except:
    print('Google drive not mounted')
print(os.listdir())
# Out:
# Google drive not mounted
# ['feedforwardAssignment.ipynb', 'CNNMNIST.ipynb', 'MNIST', 'datasets', 'data', 'ADL_Assignment_1.pdf', 'epoch_100_model.ckpt', 'template.tex', 'wandb', 'template.pdf', 'x_ray_segmentation_ERDA.ipynb', 'WandB.ipynb', 'feedForwardMNIST.ipynb']

# %% [markdown]
# ### Setup database

# %% [markdown]
# Load database with chest X-rays with lung segmentations.

# %%
data_root='./datasets'
data_npz='lung_field_dataset.npz'
data_fn = os.path.join(data_root, "lung_field_dataset.npz")
force_download = False

if (not os.path.exists(data_fn)) or force_download:
  download_url("https://sid.erda.dk/share_redirect/gCTc6o3KAh", data_root, data_npz)
else:
  print('Using existing', data_fn)

# Load train/val/test data
x_train, y_train, x_val, y_val, x_test, y_test = load_npz_dataset(data_fn)
# Bring images into PyTorch format
x_train = np.moveaxis(x_train, 3, 1)
y_train = np.moveaxis(y_train, 3, 1)
x_val = np.moveaxis(x_val, 3, 1)
y_val = np.moveaxis(y_val, 3, 1)
x_test = np.moveaxis(x_test, 3, 1)
y_test = np.moveaxis(y_test, 3, 1)

print("x train:", x_train.shape)
print("y train:", y_train.shape)
print("x val: ", x_val.shape)
print("y val: ", y_val.shape)
print("x test:", x_test.shape)
print("y test:", y_test.shape)

# Init torch datasets
train_dataset = as_torch_dataset(x_train, y_train)
val_dataset = as_torch_dataset(x_val, y_val)
test_dataset = as_torch_dataset(x_test, y_test)

# Init dataloaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)

# Plot an example
fig, ax = plot_image_with_segmentation(*train_dataset[0])
plt.show()
# Out:
# Using existing ./datasets/lung_field_dataset.npz
# x train: (112, 1, 256, 256)
# y train: (112, 1, 256, 256)
# x val:  (12, 1, 256, 256)
# y val:  (12, 1, 256, 256)
# x test: (123, 1, 256, 256)
# y test: (123, 1, 256, 256)

# %% [markdown]
# ### Init model and optimizer

# %%
# Init U-Net model
model = smp.Unet(encoder_name='efficientnet-b0',in_channels=1,classes=1)

model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)

print(model)
# Out:
# Unet(
#   (encoder): EfficientNetEncoder(
#     (_conv_stem): Conv2dStaticSamePadding(
#       1, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d((0, 1, 0, 1))
#     )
#     (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_blocks): ModuleList(
#       (0): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           32, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 32, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (1): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           96, 4, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           4, 96, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (2): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (3): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (4): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (5): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (6-7): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (8): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (9-10): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (11): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (12-14): 3 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (15): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#     )
#     (_conv_head): Conv2dStaticSamePadding(
#       320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#     (_dropout): Dropout(p=0.2, inplace=False)
#     (_swish): MemoryEfficientSwish()
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(432, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(296, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %% [markdown]
# ### Continue training?

# %%
# Specify integer, starting at 1
init_epoch = None
if init_epoch != None:
    load_model(model, f"epoch_{init_epoch}_model.ckpt", optimizer)

# %% [markdown]
# ### Run training

# %%
# Define loss and metrics
loss = torch.nn.MSELoss(reduction="mean")
metrics = {"f1": torchmetrics.classification.F1Score(task='binary', num_classes=1, average="macro")}

# Run training
train_history, val_history = training_loop(
    model=model,
    loss=loss,
    optimizer=optimizer,
    train_loader=train_loader,
    val_loader=val_loader,
    init_epoch=init_epoch,
    n_epochs=config.epochs,
    metrics_dict=metrics,
    save_path="model.ckpt"
)
# Out:
# Epoch 1/100
#    -- Batch 1/7 / Loss:  2.0845604
#    -- Batch 2/7 / Loss:  1.9686316
#    -- Batch 3/7 / Loss:  1.8527799
#    -- Batch 4/7 / Loss:  1.8379483
#    -- Batch 5/7 / Loss:  1.7601988
#    -- Batch 6/7 / Loss:  1.6567125
#    -- Batch 7/7 / Loss:  1.6392176
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.8285784}
#    Validation: {'f1': 0.30203965306282043, 'loss': 1.5751104354858398}
#    Saving to: epoch_1_model.ckpt
# Epoch 2/100
#    -- Batch 1/7 / Loss:  1.5434208
#    -- Batch 2/7 / Loss:  1.4624147
#    -- Batch 3/7 / Loss:  1.4057815
#    -- Batch 4/7 / Loss:  1.4137568
#    -- Batch 5/7 / Loss:  1.3715421
#    -- Batch 6/7 / Loss:  1.2955861
#    -- Batch 7/7 / Loss:  1.2659831
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.3940694}
#    Validation: {'f1': 0.4058014452457428, 'loss': 1.2474827766418457}
#    Saving to: epoch_2_model.ckpt
# Epoch 3/100
#    -- Batch 1/7 / Loss:  1.2441413
#    -- Batch 2/7 / Loss:  1.1573471
#    -- Batch 3/7 / Loss:  1.1283348
#    -- Batch 4/7 / Loss:  1.1834476
#    -- Batch 5/7 / Loss:  1.0737705
#    -- Batch 6/7 / Loss:  1.0191076
#    -- Batch 7/7 / Loss:  1.0132391
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.1170553}
#    Validation: {'f1': 0.46525853872299194, 'loss': 1.0174593925476074}
#    Saving to: epoch_3_model.ckpt
# Epoch 4/100
#    -- Batch 1/7 / Loss:  0.9443323
#    -- Batch 2/7 / Loss:  0.96091276
#    -- Batch 3/7 / Loss:  0.96174717
#    -- Batch 4/7 / Loss:  0.9228798
#    -- Batch 5/7 / Loss:  0.91447294
#    -- Batch 6/7 / Loss:  0.8495857
#    -- Batch 7/7 / Loss:  0.8345655
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.91264236}
#    Validation: {'f1': 0.5196268558502197, 'loss': 0.8422841429710388}
#    Saving to: epoch_4_model.ckpt
# Epoch 5/100
#    -- Batch 1/7 / Loss:  0.8289161
#    -- Batch 2/7 / Loss:  0.8186163
#    -- Batch 3/7 / Loss:  0.78216
#    -- Batch 4/7 / Loss:  0.70409065
#    -- Batch 5/7 / Loss:  0.725704
#    -- Batch 6/7 / Loss:  0.7313345
#    -- Batch 7/7 / Loss:  0.71792907
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.7583929}
#    Validation: {'f1': 0.5782212018966675, 'loss': 0.711735188961029}
#    Saving to: epoch_5_model.ckpt
# Epoch 6/100
#    -- Batch 1/7 / Loss:  0.6558516
#    -- Batch 2/7 / Loss:  0.61417556
#    -- Batch 3/7 / Loss:  0.6233915
#    -- Batch 4/7 / Loss:  0.6765345
#    -- Batch 5/7 / Loss:  0.72808194
#    -- Batch 6/7 / Loss:  0.5934808
#    -- Batch 7/7 / Loss:  0.6255197
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.6452908}
#    Validation: {'f1': 0.6520842909812927, 'loss': 0.6132065653800964}
#    Saving to: epoch_6_model.ckpt
# Epoch 7/100
#    -- Batch 1/7 / Loss:  0.5901321
#    -- Batch 2/7 / Loss:  0.59411615
#    -- Batch 3/7 / Loss:  0.5165602
#    -- Batch 4/7 / Loss:  0.55406594
#    -- Batch 5/7 / Loss:  0.5463298
#    -- Batch 6/7 / Loss:  0.53921807
#    -- Batch 7/7 / Loss:  0.5396808
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.5543004}
#    Validation: {'f1': 0.7217437028884888, 'loss': 0.5336877703666687}
#    Saving to: epoch_7_model.ckpt
# Epoch 8/100
#    -- Batch 1/7 / Loss:  0.49001557
#    -- Batch 2/7 / Loss:  0.46649164
#    -- Batch 3/7 / Loss:  0.5150765
#    -- Batch 4/7 / Loss:  0.4693395
#    -- Batch 5/7 / Loss:  0.4680549
#    -- Batch 6/7 / Loss:  0.4715383
#    -- Batch 7/7 / Loss:  0.47396883
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.47921214}
#    Validation: {'f1': 0.7694703340530396, 'loss': 0.4671599566936493}
#    Saving to: epoch_8_model.ckpt
# Epoch 9/100
#    -- Batch 1/7 / Loss:  0.4467473
#    -- Batch 2/7 / Loss:  0.41952294
#    -- Batch 3/7 / Loss:  0.44538203
#    -- Batch 4/7 / Loss:  0.39814925
#    -- Batch 5/7 / Loss:  0.3876794
#    -- Batch 6/7 / Loss:  0.42487565
#    -- Batch 7/7 / Loss:  0.3951897
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.41679236}
#    Validation: {'f1': 0.8011382222175598, 'loss': 0.40764614939689636}
#    Saving to: epoch_9_model.ckpt
# Epoch 10/100
#    -- Batch 1/7 / Loss:  0.37016293
#    -- Batch 2/7 / Loss:  0.37413254
#    -- Batch 3/7 / Loss:  0.37940755
#    -- Batch 4/7 / Loss:  0.3590985
#    -- Batch 5/7 / Loss:  0.35377926
#    -- Batch 6/7 / Loss:  0.3511204
#    -- Batch 7/7 / Loss:  0.3498373
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.3625055}
#    Validation: {'f1': 0.8211402893066406, 'loss': 0.35723528265953064}
#    Saving to: epoch_10_model.ckpt
# Epoch 11/100
#    -- Batch 1/7 / Loss:  0.33204597
#    -- Batch 2/7 / Loss:  0.3181013
#    -- Batch 3/7 / Loss:  0.32416078
#    -- Batch 4/7 / Loss:  0.347856
#    -- Batch 5/7 / Loss:  0.3054184
#    -- Batch 6/7 / Loss:  0.3013866
#    -- Batch 7/7 / Loss:  0.28335324
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.31604603}
#    Validation: {'f1': 0.8349054455757141, 'loss': 0.31421858072280884}
#    Saving to: epoch_11_model.ckpt
# Epoch 12/100
#    -- Batch 1/7 / Loss:  0.28193608
#    -- Batch 2/7 / Loss:  0.29494405
#    -- Batch 3/7 / Loss:  0.27255693
#    -- Batch 4/7 / Loss:  0.27312347
#    -- Batch 5/7 / Loss:  0.26009107
#    -- Batch 6/7 / Loss:  0.28143913
#    -- Batch 7/7 / Loss:  0.26353317
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.27537483}
#    Validation: {'f1': 0.8459206223487854, 'loss': 0.27409985661506653}
#    Saving to: epoch_12_model.ckpt
# Epoch 13/100
#    -- Batch 1/7 / Loss:  0.2639347
#    -- Batch 2/7 / Loss:  0.26843023
#    -- Batch 3/7 / Loss:  0.24107036
#    -- Batch 4/7 / Loss:  0.24808589
#    -- Batch 5/7 / Loss:  0.22245608
#    -- Batch 6/7 / Loss:  0.20794234
#    -- Batch 7/7 / Loss:  0.22509328
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23957327}
#    Validation: {'f1': 0.851112961769104, 'loss': 0.2388286143541336}
#    Saving to: epoch_13_model.ckpt
# Epoch 14/100
#    -- Batch 1/7 / Loss:  0.22254777
#    -- Batch 2/7 / Loss:  0.21870995
#    -- Batch 3/7 / Loss:  0.19430271
#    -- Batch 4/7 / Loss:  0.1961236
#    -- Batch 5/7 / Loss:  0.20390713
#    -- Batch 6/7 / Loss:  0.20828083
#    -- Batch 7/7 / Loss:  0.20955019
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20763172}
#    Validation: {'f1': 0.8506962060928345, 'loss': 0.2062017321586609}
#    Saving to: epoch_14_model.ckpt
# Epoch 15/100
#    -- Batch 1/7 / Loss:  0.18776517
#    -- Batch 2/7 / Loss:  0.16619864
#    -- Batch 3/7 / Loss:  0.18096092
#    -- Batch 4/7 / Loss:  0.18462965
#    -- Batch 5/7 / Loss:  0.19831099
#    -- Batch 6/7 / Loss:  0.16119033
#    -- Batch 7/7 / Loss:  0.17779726
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17955044}
#    Validation: {'f1': 0.8491812944412231, 'loss': 0.1805882602930069}
#    Saving to: epoch_15_model.ckpt
# Epoch 16/100
#    -- Batch 1/7 / Loss:  0.1645483
#    -- Batch 2/7 / Loss:  0.16089424
#    -- Batch 3/7 / Loss:  0.15614173
#    -- Batch 4/7 / Loss:  0.1629282
#    -- Batch 5/7 / Loss:  0.15733306
#    -- Batch 6/7 / Loss:  0.14168438
#    -- Batch 7/7 / Loss:  0.13619867
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15424694}
#    Validation: {'f1': 0.8458679914474487, 'loss': 0.15800179541110992}
#    Saving to: epoch_16_model.ckpt
# Epoch 17/100
#    -- Batch 1/7 / Loss:  0.13374087
#    -- Batch 2/7 / Loss:  0.15102914
#    -- Batch 3/7 / Loss:  0.12790321
#    -- Batch 4/7 / Loss:  0.14386427
#    -- Batch 5/7 / Loss:  0.14252934
#    -- Batch 6/7 / Loss:  0.1256984
#    -- Batch 7/7 / Loss:  0.11343804
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13402905}
#    Validation: {'f1': 0.8476983308792114, 'loss': 0.13806374371051788}
#    Saving to: epoch_17_model.ckpt
# Epoch 18/100
#    -- Batch 1/7 / Loss:  0.13011907
#    -- Batch 2/7 / Loss:  0.1278657
#    -- Batch 3/7 / Loss:  0.1367002
#    -- Batch 4/7 / Loss:  0.12593812
#    -- Batch 5/7 / Loss:  0.11126478
#    -- Batch 6/7 / Loss:  0.09985014
#    -- Batch 7/7 / Loss:  0.10955353
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.120184496}
#    Validation: {'f1': 0.8450074195861816, 'loss': 0.1240936741232872}
#    Saving to: epoch_18_model.ckpt
# Epoch 19/100
#    -- Batch 1/7 / Loss:  0.11843289
#    -- Batch 2/7 / Loss:  0.102184124
#    -- Batch 3/7 / Loss:  0.09683278
#    -- Batch 4/7 / Loss:  0.10766721
#    -- Batch 5/7 / Loss:  0.104065314
#    -- Batch 6/7 / Loss:  0.104210936
#    -- Batch 7/7 / Loss:  0.09823796
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.104518734}
#    Validation: {'f1': 0.8448519110679626, 'loss': 0.10894841700792313}
#    Saving to: epoch_19_model.ckpt
# Epoch 20/100
#    -- Batch 1/7 / Loss:  0.11449083
#    -- Batch 2/7 / Loss:  0.09241509
#    -- Batch 3/7 / Loss:  0.09981777
#    -- Batch 4/7 / Loss:  0.08252759
#    -- Batch 5/7 / Loss:  0.0933121
#    -- Batch 6/7 / Loss:  0.07732202
#    -- Batch 7/7 / Loss:  0.083386324
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09189595}
#    Validation: {'f1': 0.8445903062820435, 'loss': 0.0958719253540039}
#    Saving to: epoch_20_model.ckpt
# Epoch 21/100
#    -- Batch 1/7 / Loss:  0.08283762
#    -- Batch 2/7 / Loss:  0.08008945
#    -- Batch 3/7 / Loss:  0.08372625
#    -- Batch 4/7 / Loss:  0.080997124
#    -- Batch 5/7 / Loss:  0.07307043
#    -- Batch 6/7 / Loss:  0.08325665
#    -- Batch 7/7 / Loss:  0.07326214
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07960566}
#    Validation: {'f1': 0.8417951464653015, 'loss': 0.08522846549749374}
#    Saving to: epoch_21_model.ckpt
# Epoch 22/100
#    -- Batch 1/7 / Loss:  0.07441051
#    -- Batch 2/7 / Loss:  0.067868516
#    -- Batch 3/7 / Loss:  0.05984862
#    -- Batch 4/7 / Loss:  0.07854438
#    -- Batch 5/7 / Loss:  0.06667815
#    -- Batch 6/7 / Loss:  0.06991344
#    -- Batch 7/7 / Loss:  0.07044839
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06967314}
#    Validation: {'f1': 0.8419932723045349, 'loss': 0.07551934570074081}
#    Saving to: epoch_22_model.ckpt
# Epoch 23/100
#    -- Batch 1/7 / Loss:  0.05559016
#    -- Batch 2/7 / Loss:  0.06596514
#    -- Batch 3/7 / Loss:  0.062927194
#    -- Batch 4/7 / Loss:  0.059964113
#    -- Batch 5/7 / Loss:  0.053763174
#    -- Batch 6/7 / Loss:  0.057728067
#    -- Batch 7/7 / Loss:  0.06978488
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.060817532}
#    Validation: {'f1': 0.8343040347099304, 'loss': 0.06914419680833817}
#    Saving to: epoch_23_model.ckpt
# Epoch 24/100
#    -- Batch 1/7 / Loss:  0.052453995
#    -- Batch 2/7 / Loss:  0.05298354
#    -- Batch 3/7 / Loss:  0.05504863
#    -- Batch 4/7 / Loss:  0.058443014
#    -- Batch 5/7 / Loss:  0.050145432
#    -- Batch 6/7 / Loss:  0.05441013
#    -- Batch 7/7 / Loss:  0.055785485
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05418146}
#    Validation: {'f1': 0.8294491767883301, 'loss': 0.062132328748703}
#    Saving to: epoch_24_model.ckpt
# Epoch 25/100
#    -- Batch 1/7 / Loss:  0.048729908
#    -- Batch 2/7 / Loss:  0.050657727
#    -- Batch 3/7 / Loss:  0.05176771
#    -- Batch 4/7 / Loss:  0.0455333
#    -- Batch 5/7 / Loss:  0.051350012
#    -- Batch 6/7 / Loss:  0.048708707
#    -- Batch 7/7 / Loss:  0.045425646
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.04888186}
#    Validation: {'f1': 0.8219308257102966, 'loss': 0.05700065195560455}
#    Saving to: epoch_25_model.ckpt
# Epoch 26/100
#    -- Batch 1/7 / Loss:  0.042946234
#    -- Batch 2/7 / Loss:  0.04202313
#    -- Batch 3/7 / Loss:  0.044642102
#    -- Batch 4/7 / Loss:  0.04559484
#    -- Batch 5/7 / Loss:  0.04616799
#    -- Batch 6/7 / Loss:  0.044987492
#    -- Batch 7/7 / Loss:  0.041461267
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.04397472}
#    Validation: {'f1': 0.8193172812461853, 'loss': 0.05160342529416084}
#    Saving to: epoch_26_model.ckpt
# Epoch 27/100
#    -- Batch 1/7 / Loss:  0.042844474
#    -- Batch 2/7 / Loss:  0.040553868
#    -- Batch 3/7 / Loss:  0.037849948
#    -- Batch 4/7 / Loss:  0.045475718
#    -- Batch 5/7 / Loss:  0.038521938
#    -- Batch 6/7 / Loss:  0.038511213
#    -- Batch 7/7 / Loss:  0.03867384
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.040347286}
#    Validation: {'f1': 0.8087501525878906, 'loss': 0.048328060656785965}
#    Saving to: epoch_27_model.ckpt
# Epoch 28/100
#    -- Batch 1/7 / Loss:  0.03676395
#    -- Batch 2/7 / Loss:  0.036780555
#    -- Batch 3/7 / Loss:  0.037153732
#    -- Batch 4/7 / Loss:  0.03795661
#    -- Batch 5/7 / Loss:  0.03732565
#    -- Batch 6/7 / Loss:  0.037397865
#    -- Batch 7/7 / Loss:  0.03419857
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.036796708}
#    Validation: {'f1': 0.8061439990997314, 'loss': 0.044965166598558426}
#    Saving to: epoch_28_model.ckpt
# Epoch 29/100
#    -- Batch 1/7 / Loss:  0.032036453
#    -- Batch 2/7 / Loss:  0.039493844
#    -- Batch 3/7 / Loss:  0.03072446
#    -- Batch 4/7 / Loss:  0.035787467
#    -- Batch 5/7 / Loss:  0.030972056
#    -- Batch 6/7 / Loss:  0.032344878
#    -- Batch 7/7 / Loss:  0.03443731
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.03368521}
#    Validation: {'f1': 0.7917354106903076, 'loss': 0.04232783988118172}
#    Saving to: epoch_29_model.ckpt
# Epoch 30/100
#    -- Batch 1/7 / Loss:  0.034259416
#    -- Batch 2/7 / Loss:  0.03274732
#    -- Batch 3/7 / Loss:  0.03885992
#    -- Batch 4/7 / Loss:  0.03444761
#    -- Batch 5/7 / Loss:  0.02703303
#    -- Batch 6/7 / Loss:  0.030228823
#    -- Batch 7/7 / Loss:  0.02977195
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.032478295}
#    Validation: {'f1': 0.7869799733161926, 'loss': 0.04026853293180466}
#    Saving to: epoch_30_model.ckpt
# Epoch 31/100
#    -- Batch 1/7 / Loss:  0.027995657
#    -- Batch 2/7 / Loss:  0.032715525
#    -- Batch 3/7 / Loss:  0.033903237
#    -- Batch 4/7 / Loss:  0.035688996
#    -- Batch 5/7 / Loss:  0.028166533
#    -- Batch 6/7 / Loss:  0.028361691
#    -- Batch 7/7 / Loss:  0.025784504
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.030373735}
#    Validation: {'f1': 0.7786988615989685, 'loss': 0.03780508413910866}
#    Saving to: epoch_31_model.ckpt
# Epoch 32/100
#    -- Batch 1/7 / Loss:  0.02551778
#    -- Batch 2/7 / Loss:  0.027010329
#    -- Batch 3/7 / Loss:  0.026657281
#    -- Batch 4/7 / Loss:  0.030137733
#    -- Batch 5/7 / Loss:  0.03269671
#    -- Batch 6/7 / Loss:  0.030136492
#    -- Batch 7/7 / Loss:  0.028633973
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.02868433}
#    Validation: {'f1': 0.7634807825088501, 'loss': 0.03678662329912186}
#    Saving to: epoch_32_model.ckpt
# Epoch 33/100
#    -- Batch 1/7 / Loss:  0.026640031
#    -- Batch 2/7 / Loss:  0.028159553
#    -- Batch 3/7 / Loss:  0.026500396
#    -- Batch 4/7 / Loss:  0.027290389
#    -- Batch 5/7 / Loss:  0.026160266
#    -- Batch 6/7 / Loss:  0.024787322
#    -- Batch 7/7 / Loss:  0.024327405
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.026266482}
#    Validation: {'f1': 0.7678742408752441, 'loss': 0.03586118295788765}
#    Saving to: epoch_33_model.ckpt
# Epoch 34/100
#    -- Batch 1/7 / Loss:  0.029564086
#    -- Batch 2/7 / Loss:  0.02383673
#    -- Batch 3/7 / Loss:  0.025302611
#    -- Batch 4/7 / Loss:  0.028206475
#    -- Batch 5/7 / Loss:  0.0268195
#    -- Batch 6/7 / Loss:  0.024824219
#    -- Batch 7/7 / Loss:  0.02398451
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.026076874}
#    Validation: {'f1': 0.7629653811454773, 'loss': 0.03398105129599571}
#    Saving to: epoch_34_model.ckpt
# Epoch 35/100
#    -- Batch 1/7 / Loss:  0.024743214
#    -- Batch 2/7 / Loss:  0.025030676
#    -- Batch 3/7 / Loss:  0.026695035
#    -- Batch 4/7 / Loss:  0.022459272
#    -- Batch 5/7 / Loss:  0.023014762
#    -- Batch 6/7 / Loss:  0.023038877
#    -- Batch 7/7 / Loss:  0.026080072
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.024437414}
#    Validation: {'f1': 0.7494377493858337, 'loss': 0.03232625126838684}
#    Saving to: epoch_35_model.ckpt
# Epoch 36/100
#    -- Batch 1/7 / Loss:  0.023899466
#    -- Batch 2/7 / Loss:  0.024442196
#    -- Batch 3/7 / Loss:  0.023311697
#    -- Batch 4/7 / Loss:  0.021022335
#    -- Batch 5/7 / Loss:  0.023070194
#    -- Batch 6/7 / Loss:  0.021668961
#    -- Batch 7/7 / Loss:  0.025320666
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.02324793}
#    Validation: {'f1': 0.7405481934547424, 'loss': 0.031052110716700554}
#    Saving to: epoch_36_model.ckpt
# Epoch 37/100
#    -- Batch 1/7 / Loss:  0.023012843
#    -- Batch 2/7 / Loss:  0.021624506
#    -- Batch 3/7 / Loss:  0.021217143
#    -- Batch 4/7 / Loss:  0.025078148
#    -- Batch 5/7 / Loss:  0.026323956
#    -- Batch 6/7 / Loss:  0.022887569
#    -- Batch 7/7 / Loss:  0.020517547
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.022951674}
#    Validation: {'f1': 0.7365004420280457, 'loss': 0.030563630163669586}
#    Saving to: epoch_37_model.ckpt
# Epoch 38/100
#    -- Batch 1/7 / Loss:  0.025555123
#    -- Batch 2/7 / Loss:  0.020190058
#    -- Batch 3/7 / Loss:  0.02005395
#    -- Batch 4/7 / Loss:  0.023017248
#    -- Batch 5/7 / Loss:  0.020137422
#    -- Batch 6/7 / Loss:  0.022551956
#    -- Batch 7/7 / Loss:  0.021608112
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.02187341}
#    Validation: {'f1': 0.7246333360671997, 'loss': 0.02952151745557785}
#    Saving to: epoch_38_model.ckpt
# Epoch 39/100
#    -- Batch 1/7 / Loss:  0.02090104
#    -- Batch 2/7 / Loss:  0.022649493
#    -- Batch 3/7 / Loss:  0.018889774
#    -- Batch 4/7 / Loss:  0.021458276
#    -- Batch 5/7 / Loss:  0.021357138
#    -- Batch 6/7 / Loss:  0.023686595
#    -- Batch 7/7 / Loss:  0.021421384
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.021480529}
#    Validation: {'f1': 0.735962986946106, 'loss': 0.02982872910797596}
#    Saving to: epoch_39_model.ckpt
# Epoch 40/100
#    -- Batch 1/7 / Loss:  0.019192517
#    -- Batch 2/7 / Loss:  0.020407502
#    -- Batch 3/7 / Loss:  0.021754254
#    -- Batch 4/7 / Loss:  0.019109577
#    -- Batch 5/7 / Loss:  0.020271389
#    -- Batch 6/7 / Loss:  0.022404592
#    -- Batch 7/7 / Loss:  0.019762442
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.02041461}
#    Validation: {'f1': 0.7126243114471436, 'loss': 0.028346896171569824}
#    Saving to: epoch_40_model.ckpt
# Epoch 41/100
#    -- Batch 1/7 / Loss:  0.018579096
#    -- Batch 2/7 / Loss:  0.01873654
#    -- Batch 3/7 / Loss:  0.019433782
#    -- Batch 4/7 / Loss:  0.019875282
#    -- Batch 5/7 / Loss:  0.021613494
#    -- Batch 6/7 / Loss:  0.021452323
#    -- Batch 7/7 / Loss:  0.019411046
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.019871652}
#    Validation: {'f1': 0.7125229239463806, 'loss': 0.02808992750942707}
#    Saving to: epoch_41_model.ckpt
# Epoch 42/100
#    -- Batch 1/7 / Loss:  0.019334704
#    -- Batch 2/7 / Loss:  0.022663882
#    -- Batch 3/7 / Loss:  0.019585326
#    -- Batch 4/7 / Loss:  0.018550605
#    -- Batch 5/7 / Loss:  0.020612694
#    -- Batch 6/7 / Loss:  0.018559927
#    -- Batch 7/7 / Loss:  0.020105902
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.019916149}
#    Validation: {'f1': 0.71748948097229, 'loss': 0.027081867679953575}
#    Saving to: epoch_42_model.ckpt
# Epoch 43/100
#    -- Batch 1/7 / Loss:  0.019515611
#    -- Batch 2/7 / Loss:  0.01808207
#    -- Batch 3/7 / Loss:  0.018955031
#    -- Batch 4/7 / Loss:  0.01874767
#    -- Batch 5/7 / Loss:  0.019389885
#    -- Batch 6/7 / Loss:  0.019358318
#    -- Batch 7/7 / Loss:  0.017684726
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.018819045}
#    Validation: {'f1': 0.709610641002655, 'loss': 0.026721009984612465}
#    Saving to: epoch_43_model.ckpt
# Epoch 44/100
#    -- Batch 1/7 / Loss:  0.019013122
#    -- Batch 2/7 / Loss:  0.01744288
#    -- Batch 3/7 / Loss:  0.018948618
#    -- Batch 4/7 / Loss:  0.020176793
#    -- Batch 5/7 / Loss:  0.018821117
#    -- Batch 6/7 / Loss:  0.017140906
#    -- Batch 7/7 / Loss:  0.01775147
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.018470703}
#    Validation: {'f1': 0.7049206495285034, 'loss': 0.026091033592820168}
#    Saving to: epoch_44_model.ckpt
# Epoch 45/100
#    -- Batch 1/7 / Loss:  0.021060642
#    -- Batch 2/7 / Loss:  0.016705014
#    -- Batch 3/7 / Loss:  0.017530378
#    -- Batch 4/7 / Loss:  0.017395893
#    -- Batch 5/7 / Loss:  0.017312258
#    -- Batch 6/7 / Loss:  0.018077899
#    -- Batch 7/7 / Loss:  0.018049978
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.018018868}
#    Validation: {'f1': 0.6969401836395264, 'loss': 0.026082659140229225}
#    Saving to: epoch_45_model.ckpt
# Epoch 46/100
#    -- Batch 1/7 / Loss:  0.018195312
#    -- Batch 2/7 / Loss:  0.018549107
#    -- Batch 3/7 / Loss:  0.017041307
#    -- Batch 4/7 / Loss:  0.01693776
#    -- Batch 5/7 / Loss:  0.018090859
#    -- Batch 6/7 / Loss:  0.017830538
#    -- Batch 7/7 / Loss:  0.017208073
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.01769328}
#    Validation: {'f1': 0.7349662184715271, 'loss': 0.026901639997959137}
#    Saving to: epoch_46_model.ckpt
# Epoch 47/100
#    -- Batch 1/7 / Loss:  0.017054476
#    -- Batch 2/7 / Loss:  0.017694527
#    -- Batch 3/7 / Loss:  0.01614208
#    -- Batch 4/7 / Loss:  0.017776921
#    -- Batch 5/7 / Loss:  0.018061697
#    -- Batch 6/7 / Loss:  0.01705964
#    -- Batch 7/7 / Loss:  0.019947857
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.017676743}
#    Validation: {'f1': 0.6878560185432434, 'loss': 0.025129571557044983}
#    Saving to: epoch_47_model.ckpt
# Epoch 48/100
#    -- Batch 1/7 / Loss:  0.01667013
#    -- Batch 2/7 / Loss:  0.016671782
#    -- Batch 3/7 / Loss:  0.019466836
#    -- Batch 4/7 / Loss:  0.017382547
#    -- Batch 5/7 / Loss:  0.018689014
#    -- Batch 6/7 / Loss:  0.017583854
#    -- Batch 7/7 / Loss:  0.018462542
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.017846672}
#    Validation: {'f1': 0.68778395652771, 'loss': 0.02535189688205719}
#    Saving to: epoch_48_model.ckpt
# Epoch 49/100
#    -- Batch 1/7 / Loss:  0.016592447
#    -- Batch 2/7 / Loss:  0.016336923
#    -- Batch 3/7 / Loss:  0.017080124
#    -- Batch 4/7 / Loss:  0.01731935
#    -- Batch 5/7 / Loss:  0.016007647
#    -- Batch 6/7 / Loss:  0.016178263
#    -- Batch 7/7 / Loss:  0.018651286
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.016880862}
#    Validation: {'f1': 0.6939285397529602, 'loss': 0.024233415722846985}
#    Saving to: epoch_49_model.ckpt
# Epoch 50/100
#    -- Batch 1/7 / Loss:  0.01674585
#    -- Batch 2/7 / Loss:  0.016122138
#    -- Batch 3/7 / Loss:  0.018485226
#    -- Batch 4/7 / Loss:  0.015522176
#    -- Batch 5/7 / Loss:  0.016546126
#    -- Batch 6/7 / Loss:  0.016468406
#    -- Batch 7/7 / Loss:  0.016474837
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.016623536}
#    Validation: {'f1': 0.6919382810592651, 'loss': 0.023843703791499138}
#    Saving to: epoch_50_model.ckpt
# Epoch 51/100
#    -- Batch 1/7 / Loss:  0.015866809
#    -- Batch 2/7 / Loss:  0.015410244
#    -- Batch 3/7 / Loss:  0.01587074
#    -- Batch 4/7 / Loss:  0.017159484
#    -- Batch 5/7 / Loss:  0.015725827
#    -- Batch 6/7 / Loss:  0.016473
#    -- Batch 7/7 / Loss:  0.015985906
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.016070288}
#    Validation: {'f1': 0.6939114332199097, 'loss': 0.02450214885175228}
#    Saving to: epoch_51_model.ckpt
# Epoch 52/100
#    -- Batch 1/7 / Loss:  0.016243923
#    -- Batch 2/7 / Loss:  0.015633063
#    -- Batch 3/7 / Loss:  0.015231967
#    -- Batch 4/7 / Loss:  0.014719117
#    -- Batch 5/7 / Loss:  0.015771955
#    -- Batch 6/7 / Loss:  0.015928837
#    -- Batch 7/7 / Loss:  0.01596929
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.015642595}
#    Validation: {'f1': 0.6888281106948853, 'loss': 0.023540332913398743}
#    Saving to: epoch_52_model.ckpt
# Epoch 53/100
#    -- Batch 1/7 / Loss:  0.014688554
#    -- Batch 2/7 / Loss:  0.014565447
#    -- Batch 3/7 / Loss:  0.015585497
#    -- Batch 4/7 / Loss:  0.0154218525
#    -- Batch 5/7 / Loss:  0.014892982
#    -- Batch 6/7 / Loss:  0.015977627
#    -- Batch 7/7 / Loss:  0.016884107
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.015430868}
#    Validation: {'f1': 0.677428662776947, 'loss': 0.023456109687685966}
#    Saving to: epoch_53_model.ckpt
# Epoch 54/100
#    -- Batch 1/7 / Loss:  0.015143997
#    -- Batch 2/7 / Loss:  0.016506236
#    -- Batch 3/7 / Loss:  0.015349053
#    -- Batch 4/7 / Loss:  0.01618404
#    -- Batch 5/7 / Loss:  0.015588947
#    -- Batch 6/7 / Loss:  0.014692266
#    -- Batch 7/7 / Loss:  0.014883906
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.015478349}
#    Validation: {'f1': 0.6860200762748718, 'loss': 0.022951237857341766}
#    Saving to: epoch_54_model.ckpt
# Epoch 55/100
#    -- Batch 1/7 / Loss:  0.01598062
#    -- Batch 2/7 / Loss:  0.016573165
#    -- Batch 3/7 / Loss:  0.016958473
#    -- Batch 4/7 / Loss:  0.01565636
#    -- Batch 5/7 / Loss:  0.015563266
#    -- Batch 6/7 / Loss:  0.014855664
#    -- Batch 7/7 / Loss:  0.015020186
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.015801106}
#    Validation: {'f1': 0.7002686858177185, 'loss': 0.023282891139388084}
#    Saving to: epoch_55_model.ckpt
# Epoch 56/100
#    -- Batch 1/7 / Loss:  0.014700493
#    -- Batch 2/7 / Loss:  0.015503891
#    -- Batch 3/7 / Loss:  0.014833482
#    -- Batch 4/7 / Loss:  0.016097296
#    -- Batch 5/7 / Loss:  0.014877433
#    -- Batch 6/7 / Loss:  0.014716604
#    -- Batch 7/7 / Loss:  0.013937429
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.014952376}
#    Validation: {'f1': 0.6890020370483398, 'loss': 0.022584334015846252}
#    Saving to: epoch_56_model.ckpt
# Epoch 57/100
#    -- Batch 1/7 / Loss:  0.014089737
#    -- Batch 2/7 / Loss:  0.014830204
#    -- Batch 3/7 / Loss:  0.014040146
#    -- Batch 4/7 / Loss:  0.015048204
#    -- Batch 5/7 / Loss:  0.015596395
#    -- Batch 6/7 / Loss:  0.014163501
#    -- Batch 7/7 / Loss:  0.017373517
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.015020244}
#    Validation: {'f1': 0.6754045486450195, 'loss': 0.023464523255825043}
#    Saving to: epoch_57_model.ckpt
# Epoch 58/100
#    -- Batch 1/7 / Loss:  0.016148591
#    -- Batch 2/7 / Loss:  0.014254149
#    -- Batch 3/7 / Loss:  0.013594596
#    -- Batch 4/7 / Loss:  0.013540433
#    -- Batch 5/7 / Loss:  0.013509155
#    -- Batch 6/7 / Loss:  0.014484437
#    -- Batch 7/7 / Loss:  0.014338889
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.014267178}
#    Validation: {'f1': 0.6794108748435974, 'loss': 0.02255108207464218}
#    Saving to: epoch_58_model.ckpt
# Epoch 59/100
#    -- Batch 1/7 / Loss:  0.014217757
#    -- Batch 2/7 / Loss:  0.014225457
#    -- Batch 3/7 / Loss:  0.014922623
#    -- Batch 4/7 / Loss:  0.014844268
#    -- Batch 5/7 / Loss:  0.016238105
#    -- Batch 6/7 / Loss:  0.01320871
#    -- Batch 7/7 / Loss:  0.013655868
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.014473257}
#    Validation: {'f1': 0.7256308794021606, 'loss': 0.023435844108462334}
#    Saving to: epoch_59_model.ckpt
# Epoch 60/100
#    -- Batch 1/7 / Loss:  0.013778016
#    -- Batch 2/7 / Loss:  0.01375165
#    -- Batch 3/7 / Loss:  0.015598818
#    -- Batch 4/7 / Loss:  0.013381884
#    -- Batch 5/7 / Loss:  0.0145617435
#    -- Batch 6/7 / Loss:  0.015180335
#    -- Batch 7/7 / Loss:  0.014743087
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.014427933}
#    Validation: {'f1': 0.6930809020996094, 'loss': 0.021611995995044708}
#    Saving to: epoch_60_model.ckpt
# Epoch 61/100
#    -- Batch 1/7 / Loss:  0.01436547
#    -- Batch 2/7 / Loss:  0.013312945
#    -- Batch 3/7 / Loss:  0.013334649
#    -- Batch 4/7 / Loss:  0.015296082
#    -- Batch 5/7 / Loss:  0.01700036
#    -- Batch 6/7 / Loss:  0.013509573
#    -- Batch 7/7 / Loss:  0.013881294
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.014385767}
#    Validation: {'f1': 0.6779645681381226, 'loss': 0.021937338635325432}
#    Saving to: epoch_61_model.ckpt
# Epoch 62/100
#    -- Batch 1/7 / Loss:  0.012662112
#    -- Batch 2/7 / Loss:  0.013819066
#    -- Batch 3/7 / Loss:  0.013824873
#    -- Batch 4/7 / Loss:  0.0143712815
#    -- Batch 5/7 / Loss:  0.013158066
#    -- Batch 6/7 / Loss:  0.013082881
#    -- Batch 7/7 / Loss:  0.013414452
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0134761045}
#    Validation: {'f1': 0.6739909052848816, 'loss': 0.021565308794379234}
#    Saving to: epoch_62_model.ckpt
# Epoch 63/100
#    -- Batch 1/7 / Loss:  0.013685192
#    -- Batch 2/7 / Loss:  0.013454406
#    -- Batch 3/7 / Loss:  0.014127382
#    -- Batch 4/7 / Loss:  0.012666883
#    -- Batch 5/7 / Loss:  0.014287807
#    -- Batch 6/7 / Loss:  0.012695384
#    -- Batch 7/7 / Loss:  0.013307132
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.013460598}
#    Validation: {'f1': 0.6798378825187683, 'loss': 0.022081105038523674}
#    Saving to: epoch_63_model.ckpt
# Epoch 64/100
#    -- Batch 1/7 / Loss:  0.012976164
#    -- Batch 2/7 / Loss:  0.013766896
#    -- Batch 3/7 / Loss:  0.012597776
#    -- Batch 4/7 / Loss:  0.013386907
#    -- Batch 5/7 / Loss:  0.013663332
#    -- Batch 6/7 / Loss:  0.013307121
#    -- Batch 7/7 / Loss:  0.012941596
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.013234256}
#    Validation: {'f1': 0.6764975190162659, 'loss': 0.02158605307340622}
#    Saving to: epoch_64_model.ckpt
# Epoch 65/100
#    -- Batch 1/7 / Loss:  0.0126114
#    -- Batch 2/7 / Loss:  0.013274883
#    -- Batch 3/7 / Loss:  0.013327016
#    -- Batch 4/7 / Loss:  0.01259747
#    -- Batch 5/7 / Loss:  0.013028879
#    -- Batch 6/7 / Loss:  0.0146925505
#    -- Batch 7/7 / Loss:  0.012658813
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0131701445}
#    Validation: {'f1': 0.678830623626709, 'loss': 0.021237827837467194}
#    Saving to: epoch_65_model.ckpt
# Epoch 66/100
#    -- Batch 1/7 / Loss:  0.013323711
#    -- Batch 2/7 / Loss:  0.015769618
#    -- Batch 3/7 / Loss:  0.013300574
#    -- Batch 4/7 / Loss:  0.015643641
#    -- Batch 5/7 / Loss:  0.013171083
#    -- Batch 6/7 / Loss:  0.012657316
#    -- Batch 7/7 / Loss:  0.012522529
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.013769781}
#    Validation: {'f1': 0.6838104724884033, 'loss': 0.02108517475426197}
#    Saving to: epoch_66_model.ckpt
# Epoch 67/100
#    -- Batch 1/7 / Loss:  0.013291059
#    -- Batch 2/7 / Loss:  0.012461374
#    -- Batch 3/7 / Loss:  0.013762544
#    -- Batch 4/7 / Loss:  0.013039542
#    -- Batch 5/7 / Loss:  0.012265569
#    -- Batch 6/7 / Loss:  0.012539586
#    -- Batch 7/7 / Loss:  0.012623263
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012854706}
#    Validation: {'f1': 0.6870008111000061, 'loss': 0.020500311627984047}
#    Saving to: epoch_67_model.ckpt
# Epoch 68/100
#    -- Batch 1/7 / Loss:  0.012375861
#    -- Batch 2/7 / Loss:  0.012788892
#    -- Batch 3/7 / Loss:  0.012451694
#    -- Batch 4/7 / Loss:  0.014527937
#    -- Batch 5/7 / Loss:  0.012286374
#    -- Batch 6/7 / Loss:  0.012330158
#    -- Batch 7/7 / Loss:  0.012869503
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012804346}
#    Validation: {'f1': 0.6681773662567139, 'loss': 0.021343858912587166}
#    Saving to: epoch_68_model.ckpt
# Epoch 69/100
#    -- Batch 1/7 / Loss:  0.014529249
#    -- Batch 2/7 / Loss:  0.012098907
#    -- Batch 3/7 / Loss:  0.012862648
#    -- Batch 4/7 / Loss:  0.012601127
#    -- Batch 5/7 / Loss:  0.012720889
#    -- Batch 6/7 / Loss:  0.011917917
#    -- Batch 7/7 / Loss:  0.011814192
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012649275}
#    Validation: {'f1': 0.678696870803833, 'loss': 0.020654350519180298}
#    Saving to: epoch_69_model.ckpt
# Epoch 70/100
#    -- Batch 1/7 / Loss:  0.012382284
#    -- Batch 2/7 / Loss:  0.013990393
#    -- Batch 3/7 / Loss:  0.012970237
#    -- Batch 4/7 / Loss:  0.011712115
#    -- Batch 5/7 / Loss:  0.011507358
#    -- Batch 6/7 / Loss:  0.012337838
#    -- Batch 7/7 / Loss:  0.012127943
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012432597}
#    Validation: {'f1': 0.6782397627830505, 'loss': 0.020352941006422043}
#    Saving to: epoch_70_model.ckpt
# Epoch 71/100
#    -- Batch 1/7 / Loss:  0.012820419
#    -- Batch 2/7 / Loss:  0.011872444
#    -- Batch 3/7 / Loss:  0.012262833
#    -- Batch 4/7 / Loss:  0.012553071
#    -- Batch 5/7 / Loss:  0.012478817
#    -- Batch 6/7 / Loss:  0.012040742
#    -- Batch 7/7 / Loss:  0.015215775
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012749158}
#    Validation: {'f1': 0.670447826385498, 'loss': 0.020608961582183838}
#    Saving to: epoch_71_model.ckpt
# Epoch 72/100
#    -- Batch 1/7 / Loss:  0.011473903
#    -- Batch 2/7 / Loss:  0.0138107315
#    -- Batch 3/7 / Loss:  0.01229014
#    -- Batch 4/7 / Loss:  0.011733666
#    -- Batch 5/7 / Loss:  0.012422191
#    -- Batch 6/7 / Loss:  0.012522859
#    -- Batch 7/7 / Loss:  0.011564191
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012259669}
#    Validation: {'f1': 0.6760915517807007, 'loss': 0.02049715258181095}
#    Saving to: epoch_72_model.ckpt
# Epoch 73/100
#    -- Batch 1/7 / Loss:  0.012324056
#    -- Batch 2/7 / Loss:  0.01262752
#    -- Batch 3/7 / Loss:  0.011423158
#    -- Batch 4/7 / Loss:  0.011560647
#    -- Batch 5/7 / Loss:  0.012480896
#    -- Batch 6/7 / Loss:  0.012390332
#    -- Batch 7/7 / Loss:  0.011443621
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012035748}
#    Validation: {'f1': 0.6814680099487305, 'loss': 0.02032015286386013}
#    Saving to: epoch_73_model.ckpt
# Epoch 74/100
#    -- Batch 1/7 / Loss:  0.012581399
#    -- Batch 2/7 / Loss:  0.012661902
#    -- Batch 3/7 / Loss:  0.0129578095
#    -- Batch 4/7 / Loss:  0.011614202
#    -- Batch 5/7 / Loss:  0.012375582
#    -- Batch 6/7 / Loss:  0.0117567135
#    -- Batch 7/7 / Loss:  0.011831299
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012254129}
#    Validation: {'f1': 0.6806089878082275, 'loss': 0.02035978063941002}
#    Saving to: epoch_74_model.ckpt
# Epoch 75/100
#    -- Batch 1/7 / Loss:  0.011346936
#    -- Batch 2/7 / Loss:  0.01232392
#    -- Batch 3/7 / Loss:  0.012064793
#    -- Batch 4/7 / Loss:  0.011895551
#    -- Batch 5/7 / Loss:  0.011263831
#    -- Batch 6/7 / Loss:  0.011026527
#    -- Batch 7/7 / Loss:  0.012119266
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.011720116}
#    Validation: {'f1': 0.6779324412345886, 'loss': 0.01988391764461994}
#    Saving to: epoch_75_model.ckpt
# Epoch 76/100
#    -- Batch 1/7 / Loss:  0.012231368
#    -- Batch 2/7 / Loss:  0.012703813
#    -- Batch 3/7 / Loss:  0.011918159
#    -- Batch 4/7 / Loss:  0.011335589
#    -- Batch 5/7 / Loss:  0.011893731
#    -- Batch 6/7 / Loss:  0.011296536
#    -- Batch 7/7 / Loss:  0.011682058
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.011865892}
#    Validation: {'f1': 0.6762850284576416, 'loss': 0.02018439583480358}
#    Saving to: epoch_76_model.ckpt
# Epoch 77/100
#    -- Batch 1/7 / Loss:  0.012938066
#    -- Batch 2/7 / Loss:  0.013677377
#    -- Batch 3/7 / Loss:  0.010751676
#    -- Batch 4/7 / Loss:  0.011691257
#    -- Batch 5/7 / Loss:  0.010998728
#    -- Batch 6/7 / Loss:  0.011437312
#    -- Batch 7/7 / Loss:  0.012674106
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.012024075}
#    Validation: {'f1': 0.7170327305793762, 'loss': 0.020682111382484436}
#    Saving to: epoch_77_model.ckpt
# Epoch 78/100
#    -- Batch 1/7 / Loss:  0.012324566
#    -- Batch 2/7 / Loss:  0.01132576
#    -- Batch 3/7 / Loss:  0.011631671
#    -- Batch 4/7 / Loss:  0.011312244
#    -- Batch 5/7 / Loss:  0.01177807
#    -- Batch 6/7 / Loss:  0.012216617
#    -- Batch 7/7 / Loss:  0.011175787
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.011680675}
#    Validation: {'f1': 0.6806227564811707, 'loss': 0.019547371193766594}
#    Saving to: epoch_78_model.ckpt
# Epoch 79/100
#    -- Batch 1/7 / Loss:  0.011133873
#    -- Batch 2/7 / Loss:  0.011797212
#    -- Batch 3/7 / Loss:  0.011154068
#    -- Batch 4/7 / Loss:  0.010892873
#    -- Batch 5/7 / Loss:  0.011185762
#    -- Batch 6/7 / Loss:  0.012050959
#    -- Batch 7/7 / Loss:  0.011020962
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.011319386}
#    Validation: {'f1': 0.6796787977218628, 'loss': 0.01958700828254223}
#    Saving to: epoch_79_model.ckpt
# Epoch 80/100
#    -- Batch 1/7 / Loss:  0.010815207
#    -- Batch 2/7 / Loss:  0.010649088
#    -- Batch 3/7 / Loss:  0.010756226
#    -- Batch 4/7 / Loss:  0.010980849
#    -- Batch 5/7 / Loss:  0.011175891
#    -- Batch 6/7 / Loss:  0.012509277
#    -- Batch 7/7 / Loss:  0.012411671
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.011328315}
#    Validation: {'f1': 0.7052363157272339, 'loss': 0.020069045946002007}
#    Saving to: epoch_80_model.ckpt
# Epoch 81/100
#    -- Batch 1/7 / Loss:  0.0112263765
#    -- Batch 2/7 / Loss:  0.011115745
#    -- Batch 3/7 / Loss:  0.010873543
#    -- Batch 4/7 / Loss:  0.011415446
#    -- Batch 5/7 / Loss:  0.010895327
#    -- Batch 6/7 / Loss:  0.0113747325
#    -- Batch 7/7 / Loss:  0.011524074
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.011203607}
#    Validation: {'f1': 0.6819599270820618, 'loss': 0.019390234723687172}
#    Saving to: epoch_81_model.ckpt
# Epoch 82/100
#    -- Batch 1/7 / Loss:  0.010816404
#    -- Batch 2/7 / Loss:  0.011739548
#    -- Batch 3/7 / Loss:  0.0106999
#    -- Batch 4/7 / Loss:  0.010644559
#    -- Batch 5/7 / Loss:  0.010428686
#    -- Batch 6/7 / Loss:  0.010573101
#    -- Batch 7/7 / Loss:  0.011045048
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010849607}
#    Validation: {'f1': 0.680864691734314, 'loss': 0.019367123022675514}
#    Saving to: epoch_82_model.ckpt
# Epoch 83/100
#    -- Batch 1/7 / Loss:  0.010316491
#    -- Batch 2/7 / Loss:  0.010210622
#    -- Batch 3/7 / Loss:  0.011745751
#    -- Batch 4/7 / Loss:  0.010609314
#    -- Batch 5/7 / Loss:  0.010999735
#    -- Batch 6/7 / Loss:  0.01036974
#    -- Batch 7/7 / Loss:  0.010115389
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010623864}
#    Validation: {'f1': 0.6826139092445374, 'loss': 0.019301705062389374}
#    Saving to: epoch_83_model.ckpt
# Epoch 84/100
#    -- Batch 1/7 / Loss:  0.010289755
#    -- Batch 2/7 / Loss:  0.010165623
#    -- Batch 3/7 / Loss:  0.011226632
#    -- Batch 4/7 / Loss:  0.010707835
#    -- Batch 5/7 / Loss:  0.011413127
#    -- Batch 6/7 / Loss:  0.010736637
#    -- Batch 7/7 / Loss:  0.010558093
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010728243}
#    Validation: {'f1': 0.6828155517578125, 'loss': 0.019285045564174652}
#    Saving to: epoch_84_model.ckpt
# Epoch 85/100
#    -- Batch 1/7 / Loss:  0.010569282
#    -- Batch 2/7 / Loss:  0.010019172
#    -- Batch 3/7 / Loss:  0.01105719
#    -- Batch 4/7 / Loss:  0.010452765
#    -- Batch 5/7 / Loss:  0.011789118
#    -- Batch 6/7 / Loss:  0.0101064835
#    -- Batch 7/7 / Loss:  0.011399724
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010770534}
#    Validation: {'f1': 0.6814395189285278, 'loss': 0.019087165594100952}
#    Saving to: epoch_85_model.ckpt
# Epoch 86/100
#    -- Batch 1/7 / Loss:  0.010999331
#    -- Batch 2/7 / Loss:  0.010918163
#    -- Batch 3/7 / Loss:  0.010022883
#    -- Batch 4/7 / Loss:  0.010081071
#    -- Batch 5/7 / Loss:  0.011200357
#    -- Batch 6/7 / Loss:  0.010275826
#    -- Batch 7/7 / Loss:  0.010854078
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010621673}
#    Validation: {'f1': 0.6843498945236206, 'loss': 0.019148489460349083}
#    Saving to: epoch_86_model.ckpt
# Epoch 87/100
#    -- Batch 1/7 / Loss:  0.010938831
#    -- Batch 2/7 / Loss:  0.010295526
#    -- Batch 3/7 / Loss:  0.010710038
#    -- Batch 4/7 / Loss:  0.010542674
#    -- Batch 5/7 / Loss:  0.010428247
#    -- Batch 6/7 / Loss:  0.010360518
#    -- Batch 7/7 / Loss:  0.010491559
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010538199}
#    Validation: {'f1': 0.6783444285392761, 'loss': 0.018568968400359154}
#    Saving to: epoch_87_model.ckpt
# Epoch 88/100
#    -- Batch 1/7 / Loss:  0.010231568
#    -- Batch 2/7 / Loss:  0.011119589
#    -- Batch 3/7 / Loss:  0.011213419
#    -- Batch 4/7 / Loss:  0.0105282515
#    -- Batch 5/7 / Loss:  0.01071441
#    -- Batch 6/7 / Loss:  0.010836908
#    -- Batch 7/7 / Loss:  0.010815573
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.01077996}
#    Validation: {'f1': 0.6823922395706177, 'loss': 0.018710292875766754}
#    Saving to: epoch_88_model.ckpt
# Epoch 89/100
#    -- Batch 1/7 / Loss:  0.010591189
#    -- Batch 2/7 / Loss:  0.010967577
#    -- Batch 3/7 / Loss:  0.011027223
#    -- Batch 4/7 / Loss:  0.010865925
#    -- Batch 5/7 / Loss:  0.010709137
#    -- Batch 6/7 / Loss:  0.010631852
#    -- Batch 7/7 / Loss:  0.009960625
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010679075}
#    Validation: {'f1': 0.6743979454040527, 'loss': 0.018627842888236046}
#    Saving to: epoch_89_model.ckpt
# Epoch 90/100
#    -- Batch 1/7 / Loss:  0.010644162
#    -- Batch 2/7 / Loss:  0.010618108
#    -- Batch 3/7 / Loss:  0.010176016
#    -- Batch 4/7 / Loss:  0.010040512
#    -- Batch 5/7 / Loss:  0.0107258195
#    -- Batch 6/7 / Loss:  0.010439967
#    -- Batch 7/7 / Loss:  0.009814187
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010351254}
#    Validation: {'f1': 0.6673675179481506, 'loss': 0.018347343429923058}
#    Saving to: epoch_90_model.ckpt
# Epoch 91/100
#    -- Batch 1/7 / Loss:  0.009266701
#    -- Batch 2/7 / Loss:  0.010452928
#    -- Batch 3/7 / Loss:  0.010820173
#    -- Batch 4/7 / Loss:  0.009719161
#    -- Batch 5/7 / Loss:  0.0102928355
#    -- Batch 6/7 / Loss:  0.009910312
#    -- Batch 7/7 / Loss:  0.009939898
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.01005743}
#    Validation: {'f1': 0.7463328242301941, 'loss': 0.019499199464917183}
#    Saving to: epoch_91_model.ckpt
# Epoch 92/100
#    -- Batch 1/7 / Loss:  0.011310483
#    -- Batch 2/7 / Loss:  0.009814249
#    -- Batch 3/7 / Loss:  0.0100238165
#    -- Batch 4/7 / Loss:  0.009884352
#    -- Batch 5/7 / Loss:  0.009887671
#    -- Batch 6/7 / Loss:  0.010825425
#    -- Batch 7/7 / Loss:  0.010190015
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010276574}
#    Validation: {'f1': 0.6799758672714233, 'loss': 0.018879612907767296}
#    Saving to: epoch_92_model.ckpt
# Epoch 93/100
#    -- Batch 1/7 / Loss:  0.010540083
#    -- Batch 2/7 / Loss:  0.009773903
#    -- Batch 3/7 / Loss:  0.009954258
#    -- Batch 4/7 / Loss:  0.010630328
#    -- Batch 5/7 / Loss:  0.009879653
#    -- Batch 6/7 / Loss:  0.0103282705
#    -- Batch 7/7 / Loss:  0.010165559
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.010181722}
#    Validation: {'f1': 0.673707902431488, 'loss': 0.018634604290127754}
#    Saving to: epoch_93_model.ckpt
# Epoch 94/100
#    -- Batch 1/7 / Loss:  0.010972079
#    -- Batch 2/7 / Loss:  0.010491839
#    -- Batch 3/7 / Loss:  0.009762814
#    -- Batch 4/7 / Loss:  0.009766873
#    -- Batch 5/7 / Loss:  0.009877253
#    -- Batch 6/7 / Loss:  0.0107429605
#    -- Batch 7/7 / Loss:  0.009617581
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0101759145}
#    Validation: {'f1': 0.6778866052627563, 'loss': 0.01828542910516262}
#    Saving to: epoch_94_model.ckpt
# Epoch 95/100
#    -- Batch 1/7 / Loss:  0.010043244
#    -- Batch 2/7 / Loss:  0.010101411
#    -- Batch 3/7 / Loss:  0.011098096
#    -- Batch 4/7 / Loss:  0.009741628
#    -- Batch 5/7 / Loss:  0.009846233
#    -- Batch 6/7 / Loss:  0.009392962
#    -- Batch 7/7 / Loss:  0.009328585
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.009936022}
#    Validation: {'f1': 0.6885793805122375, 'loss': 0.017988093197345734}
#    Saving to: epoch_95_model.ckpt
# Epoch 96/100
#    -- Batch 1/7 / Loss:  0.009778824
#    -- Batch 2/7 / Loss:  0.009707173
#    -- Batch 3/7 / Loss:  0.009358186
#    -- Batch 4/7 / Loss:  0.0093338955
#    -- Batch 5/7 / Loss:  0.009067949
#    -- Batch 6/7 / Loss:  0.010235548
#    -- Batch 7/7 / Loss:  0.009885377
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.00962385}
#    Validation: {'f1': 0.6860429644584656, 'loss': 0.018224122002720833}
#    Saving to: epoch_96_model.ckpt
# Epoch 97/100
#    -- Batch 1/7 / Loss:  0.009929048
#    -- Batch 2/7 / Loss:  0.00945087
#    -- Batch 3/7 / Loss:  0.009824865
#    -- Batch 4/7 / Loss:  0.009093296
#    -- Batch 5/7 / Loss:  0.009295913
#    -- Batch 6/7 / Loss:  0.010308638
#    -- Batch 7/7 / Loss:  0.010651665
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.009793471}
#    Validation: {'f1': 0.6807922720909119, 'loss': 0.018207162618637085}
#    Saving to: epoch_97_model.ckpt
# Epoch 98/100
#    -- Batch 1/7 / Loss:  0.009977305
#    -- Batch 2/7 / Loss:  0.0098354835
#    -- Batch 3/7 / Loss:  0.010065986
#    -- Batch 4/7 / Loss:  0.009714673
#    -- Batch 5/7 / Loss:  0.008983359
#    -- Batch 6/7 / Loss:  0.010229198
#    -- Batch 7/7 / Loss:  0.00933384
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.009734264}
#    Validation: {'f1': 0.684692919254303, 'loss': 0.018038278445601463}
#    Saving to: epoch_98_model.ckpt
# Epoch 99/100
#    -- Batch 1/7 / Loss:  0.0091594225
#    -- Batch 2/7 / Loss:  0.009839831
#    -- Batch 3/7 / Loss:  0.009506067
#    -- Batch 4/7 / Loss:  0.010071498
#    -- Batch 5/7 / Loss:  0.010905083
#    -- Batch 6/7 / Loss:  0.01053471
#    -- Batch 7/7 / Loss:  0.0087682605
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0098264115}
#    Validation: {'f1': 0.6739086508750916, 'loss': 0.017827138304710388}
#    Saving to: epoch_99_model.ckpt
# Epoch 100/100
#    -- Batch 1/7 / Loss:  0.009462468
#    -- Batch 2/7 / Loss:  0.009636604
#    -- Batch 3/7 / Loss:  0.010093363
#    -- Batch 4/7 / Loss:  0.009609954
#    -- Batch 5/7 / Loss:  0.009213284
#    -- Batch 6/7 / Loss:  0.010862801
#    -- Batch 7/7 / Loss:  0.009667101
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0097922245}
#    Validation: {'f1': 0.676741898059845, 'loss': 0.017908917739987373}
#    Saving to: epoch_100_model.ckpt

# %% [markdown]
# ### Plot training and validation histories

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.show()

# %% [markdown]
# ### Evaluate on single test-set image

# %%
# Select a test image
x,y = test_dataset[0]
pred = evaluate_model_on_single_image(model, x)

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")
plot_image_with_segmentation(x, y, ax=ax1)
plot_image_with_segmentation(x, pred, ax=ax2)
plt.show()

# %% [markdown]
# ### Evaluate on whole test-set

# %%
# OBS: Returns batch-wise metrics, but test_loader has batch_size = 1
f1_test_scores = evaluate_model(model, test_loader, metrics, reduction=False)["f1"]

print("Test cases:", len(f1_test_scores))
print("Mean F1:   ", np.mean(f1_test_scores))
print("STD  F1:   ", np.std(f1_test_scores))
print("Min. F1:   ", np.min(f1_test_scores))
# Out:
# Test cases: 123
# Mean F1:    0.822805714801075
# STD  F1:    0.07112963603537314
# Min. F1:    0.6012150049209595

# %%
sum(p.numel() for p in model.parameters())
# Out:
# 6250893

# %% [markdown]
# # Structure of the file
# ## Data processing
#     - load data
#     - transform into tensor
#     - wrap datasets as dataloaders
# ## Initializing the model and the optimizer
#     - set model structure
#     - select optimizer and learning rate
# ## Training
#     - load a batch of samples
#     - forward propagation
#     - calculate loss
#     - back propagation
#     - update model parameters
#     - evaluate model
#     - log
# ## Evaluation
#     - single sample evaluation and visualization
#     - evaluate the model on the whole dataset
